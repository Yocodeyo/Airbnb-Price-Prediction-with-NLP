# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np

# %%
pathlistings = '/content/gdrive/My Drive/BT4222 project/afterfeatureengineering2.csv'
df_listings_dummy = pd.read_csv(pathlistings)
len(df_listings_dummy)
# Out:
# 99990

# %%
df_listings_dummy.head()
# Out:
#    Central Park  Times Square  ...  room_type_Private room  room_type_Shared room
# 0      6.290352      3.370646  ...                       0                      0
# 1     11.087517      9.054114  ...                       1                      0
# 2      9.598588      6.847807  ...                       1                      0
# 3      9.359295      6.105582  ...                       0                      0
# 4     13.629902     10.650841  ...                       0                      0
#
# [5 rows x 325 columns]

# %%
# df_listings_dummy.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# indices = list(np.where(df_listings_dummy['price'].isna()))
# len(indices)
# print(indices)
# Out:
# [array([], dtype=int64)]

# %%
# df_listings_dummy[df_listings_dummy['cleaning_fee'].isna()]
# Out:
#        Central Park  ...  room_type_Shared room
# 2          9.598588  ...                      0
# 3          9.359295  ...                      0
# 6         10.784933  ...                      0
# 12        12.973836  ...                      0
# 22         3.083326  ...                      0
# ...             ...  ...                    ...
# 99975     10.796292  ...                      0
# 99977      4.276407  ...                      0
# 99978     15.667669  ...                      0
# 99982      8.358524  ...                      0
# 99984      8.469483  ...                      0
#
# [22979 rows x 324 columns]

# %%
# df_listings_dummy.review_scores_rating
# Out:
# 0        100.0
# 1        100.0
# 2          NaN
# 3         86.0
# 4        100.0
#          ...
# 99985     94.0
# 99986     90.0
# 99987      NaN
# 99988    100.0
# 99989      NaN
# Name: review_scores_rating, Length: 99990, dtype: float64

# %%
# df_listings_dummy["review_scores_rating"].fillna(0, inplace = True)

# %%
df_listings_dummy.review_scores_rating
# Out:
# 0        100.0
# 1        100.0
# 2          0.0
# 3         86.0
# 4        100.0
#          ...
# 99985     94.0
# 99986     90.0
# 99987      0.0
# 99988    100.0
# 99989      0.0
# Name: review_scores_rating, Length: 99990, dtype: float64

# %%
# df_listings_dummy["cleaning_fee"].fillna(0, inplace = True)

# %%
df_listings_dummy.cleaning_fee
# Out:
# 0        100.0
# 1         40.0
# 2          0.0
# 3          0.0
# 4        100.0
#          ...
# 99985     60.0
# 99986     95.0
# 99987     20.0
# 99988      0.0
# 99989     25.0
# Name: cleaning_fee, Length: 99990, dtype: float64

# %%
df_listings_dummy.shape
# Out:
# (99990, 325)

# %%
X = df_listings_dummy.drop(columns=['price'])
y = df_listings_dummy.price

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
print(X_train.shape)
print(X_test.shape)
# Out:
# (74992, 324)
# (24998, 324)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
gbrt = GradientBoostingRegressor(n_estimators=100) 
gbrt.fit(X_train, y_train)
y_train_pred = gbrt.predict(X_train)
y_test_pred = gbrt.predict(X_test)

# %%
print("training RMSE: ", mean_squared_error(y_train, y_train_pred, squared=False))
print("training R2: ", r2_score(y_train, y_train_pred))
print("testing RMSE: ", mean_squared_error(y_test, y_test_pred, squared=False))
print("testing R2: ", r2_score(y_test, y_test_pred))
# Out:
# training RMSE:  173.65558368302956
# training R2:  0.5539072735776882
# testing RMSE:  175.96395651659142
# testing R2:  0.42082015613920554

# %%
from sklearn.model_selection import RandomizedSearchCV
# parameters = {
#     "loss":["ls", "lad"],#,"huber"],
#     "learning_rate": [0.05, 0.1, 0.2],
#     "min_samples_split": [0.1,2],
#     "min_samples_leaf": [0.1,1],
#     #"max_depth":[3,5,8],
#     "max_features":["log2"],
#     "criterion": ["friedman_mse"],
#     #"subsample": [ 0.8, 1.0],
#     "n_estimators":[100, 150]
#     }

gradb = RandomizedSearchCV(estimator = GradientBoostingRegressor(), param_distributions = parameters, n_iter = 50, cv = 5, n_jobs = -1)
gradb.fit(X_train, y_train)
# clf = GridSearchCV(GradientBoostingRegressor(), parameters, cv=3, n_jobs=-1，scoring="neg_root_mean_squared")

# clf.fit(X_train, y_train)
# print(clf.score(X_train, y_train))
# print(clf.best_params_)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:281: UserWarning: The total space of parameters 48 is smaller than n_iter=50. Running 48 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0,
#                                                        criterion='friedman_mse',
#                                                        init=None,
#                                                        learning_rate=0.1,
#                                                        loss='ls', max_depth=3,
#                                                        max_features=None,
#                                                        max_leaf_nodes=None,
#                                                        min_impurity_decrease=0.0,
# ...

# %%
parameters = {
    "loss":["ls", "lad","huber"],
    "learning_rate": [0.01, 0.05, 0.1, 0.15, 0.2],
    "min_samples_split": np.linspace(0.1, 0.5, 12),
    "min_samples_leaf": np.linspace(0.1, 0.5, 12),
    #"max_depth":[3,5,8],
    "max_features":["log2", None, "sqrt"],
    "criterion": ["friedman_mse" ],
    "subsample": [0.5, 0.8, 1.0],
    "n_estimators":[100, 150, 200]
    }

# %%
clf = GridSearchCV(estimator=GradientBoostingRegressor(), param_grid = parameters, cv=5,n_jobs = -1, scoring ='neg_root_mean_squared_error')
clf.fit(X_train, y_train)
print(clf.score(X_train, y_train))
print(clf.best_params_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-9ba4805f868d> in <module>()
#       1
#       2 clf = GridSearchCV(estimator=GradientBoostingRegressor(), param_grid = parameters, cv=5,n_jobs = -1, scoring ='neg_root_mean_squared_error')
# ----> 3 clf.fit(X_train, y_train)
#       4 print(clf.score(X_train, y_train))
#       5 print(clf.best_params_)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
# ...

# %%
y_test_pred1 = clf.predict(X_test)

# %%
print("testing RMSE: ", mean_squared_error(y_test, y_test_pred1, squared=False))
print("testing R2: ", r2_score(y_test, y_test_pred1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3c1a52d1f72d> in <module>()
# ----> 1 print("testing RMSE: ", mean_squared_error(y_test, y_test_pred1, squared=False))
#       2 print("testing R2: ", r2_score(y_test, y_test_pred1))
#
# NameError: name 'mean_squared_error' is not defined
