# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np
pathlistings = '/content/gdrive/My Drive/BT4222 project/afterfeatureengineering2.csv'
df_listings = pd.read_csv(pathlistings)
len(df_listings)
X = df_listings.drop(columns=['price'])
y = df_listings.price

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
print(X_train.shape)
print(X_test.shape)
# Out:
# (74992, 324)
# (24998, 324)

# %%
import xgboost
from sklearn.model_selection import GridSearchCV

xgb=xgboost.XGBRegressor(random_state=4)
grid_values = {'n_estimators':[300,350,400,450],'max_depth': [4,5,6,7,8,9],'gamma':[0,0.1,0.2,0.3],'colsample_bytree':[0.7,0.8,0.9,1]}
grid_xgb = GridSearchCV(xgb, param_grid = grid_values,cv=5,scoring='neg_root_mean_squared_error')
grid_xgb.fit(X_train, y_train)
grid_xgb.best_params_

# %%
import xgboost
from sklearn.model_selection import GridSearchCV
xgb=xgboost.XGBRegressor(n_estimators=400,max_depth=8,random_state=4)
xgb.fit(X_train, y_train)


#standard deviation
print(np.std(y_test))
pd.DataFrame({'feature':X.columns, 'importance':xgb.feature_importances_}).sort_values(by='importance', ascending=False).head(50)
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
y_train_pred = xgb.predict(X_train)
y_pred = xgb.predict(X_test)
# RMSE
print("training RMSE: ", mean_squared_error(y_train, y_train_pred, squared=False))
print("testing RMSE",mean_squared_error(y_test, y_pred, squared=False))
#r2
print("training R2: ", r2_score(y_train, y_train_pred))
print("testing R2: ", r2_score(y_test, y_pred))
#standard deviation
print(np.std(y_test))
# Out:
# [06:41:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 231.2155288354705
# training RMSE:  44.55558968652868
# testing RMSE 149.34811923096814
# training R2:  0.9706335107677464
# testing R2:  0.5827796161993533
# 231.2155288354705

# %%
pd.DataFrame({'feature':X.columns, 'importance':xgb.feature_importances_}).sort_values(by='importance', ascending=False).head(20)
# Out:
#                              feature  importance
# 259    neighbourhood_Upper West Side    0.190708
# 181    neighbourhood_Lower East Side    0.079509
# 141       neighbourhood_Forest Hills    0.051320
# 320        room_type_Entire home/apt    0.046585
# 76   neighbourhood_Battery Park City    0.034591
# 23                         bathrooms    0.027097
# 282               property_type_Boat    0.025826
# 57                     sentiment_avg    0.023746
# 283     property_type_Boutique hotel    0.021554
# 87        neighbourhood_Borough Park    0.020009
# 21                      accommodates    0.017467
# 311             property_type_Resort    0.015772
# 106       neighbourhood_Clinton Hill    0.015372
# 95            neighbourhood_Bushwick    0.014757
# 20                        within_2km    0.014137
# 8                          High Line    0.012882
# 128       neighbourhood_East Village    0.012837
# 137  neighbourhood_Flatiron District    0.012402
# 1                       Times Square    0.011708
# 310              property_type_Other    0.011185

# %%
pd.DataFrame({'feature':X.columns, 'importance':xgb.feature_importances_}).sort_values(by='importance', ascending=False).tail(123).feature.tolist()
# Out:
# ['property_type_Bungalow',
#  'neighbourhood_The Rockaways',
#  'property_type_In-law',
#  'property_type_Island',
#  'property_type_Casa particular (Cuba)',
#  'property_type_Lighthouse',
#  'property_type_Nature lodge',
#  'property_type_Bus',
#  'property_type_Chalet',
#  'property_type_Tiny house',
#  'neighbourhood_South Street Seaport',
#  'neighbourhood_Throgs Neck',
#  'property_type_Treehouse',
#  'neighbourhood_Woodhaven',
#  'property_type_Vacation home',
#  'neighbourhood_St. George',
#  'property_type_Villa',
#  'neighbourhood_Spuyten Duyvil',
#  'property_type_Barn',
#  'neighbourhood_Todt Hill',
#  'property_type_Hut',
#  'neighbourhood_Woodlawn',
#  'neighbourhood_Wakefield',
#  'property_type_Dome house',
#  'property_type_Dorm',
#  'property_type_Cave',
#  'property_type_Earth house',
#  'neighbourhood_West Brighton',
#  'neighbourhood_West Farms',
#  'property_type_Farm stay',
#  'neighbourhood_Whitestone',
#  'neighbourhood_Westchester Village',
#  'property_type_Hostel',
#  'property_type_Houseboat',
#  'neighbourhood_Tremont',
#  'neighbourhood_Tottenville',
#  'neighbourhood_Tompkinsville',
#  'property_type_Cottage',
#  'neighbourhood_University Heights',
#  'neighbourhood_Baychester',
#  'neighbourhood_South Beach',
#  'neighbourhood_Coney Island',
#  'neighbourhood_Country Club',
#  'neighbourhood_Crotona',
#  'neighbourhood_DUMBO',
#  'neighbourhood_Dongan Hills',
#  'neighbourhood_Dyker Heights',
#  'neighbourhood_Annadale',
#  'neighbourhood_Eastchester',
#  'neighbourhood_Edenwald',
#  'neighbourhood_Elm Park',
#  'neighbourhood_Elmhurst',
#  'neighbourhood_Eltingville',
#  'neighbourhood_Emerson Hill',
#  'neighbourhood_Flatlands',
#  'neighbourhood_Allerton',
#  'neighbourhood_Fort Hamilton',
#  'neighbourhood_Fort Wadsworth',
#  'neighbourhood_Fresh Meadows',
#  'neighbourhood_Corona',
#  'neighbourhood_Concourse',
#  'neighbourhood_Grant City',
#  'neighbourhood_Concord',
#  'neighbourhood_Bedford Park',
#  'neighbourhood_Bay Terrace',
#  'neighbourhood_Belmont',
#  'neighbourhood_Bensonhurst',
#  'neighbourhood_Bergen Beach',
#  'neighbourhood_Brighton Beach',
#  'neighbourhood_Bronxdale',
#  'neighbourhood_Brownsville',
#  "neighbourhood_Bull's Head",
#  'neighbourhood_Bath Beach',
#  'neighbourhood_Castle Hill ',
#  'neighbourhood_Castleton Corners',
#  'neighbourhood_City Island',
#  'neighbourhood_Claremont',
#  'neighbourhood_Clifton',
#  'neighbourhood_Co-op City',
#  'neighbourhood_Columbia Street Waterfront',
#  'neighbourhood_Graniteville',
#  'neighbourhood_Grasmere',
#  'neighbourhood_Silver Lake',
#  'neighbourhood_Morris Heights',
#  'neighbourhood_Bayside',
#  'neighbourhood_New Dorp',
#  'neighbourhood_New Dorp Beach',
#  'neighbourhood_New Springville',
#  'neighbourhood_Norwood',
#  'neighbourhood_Oakwood',
#  'neighbourhood_Ocean Breeze',
#  'neighbourhood_Park Versailles',
#  'neighbourhood_Parkchester',
#  'neighbourhood_Pleasant Plains',
#  'neighbourhood_Port Richmond',
#  "neighbourhood_Prince's Bay",
#  'neighbourhood_Randall Manor',
#  'neighbourhood_Red Hook',
#  'neighbourhood_Rosebank',
#  'neighbourhood_Rossville',
#  'neighbourhood_Sea Gate',
#  'neighbourhood_Morrisania',
#  'neighbourhood_Mill Basin',
#  'neighbourhood_Great Kills',
#  'neighbourhood_Midwood',
#  'neighbourhood_Howard Beach',
#  'neighbourhood_Hunts Point',
#  'neighbourhood_Inwood',
#  'neighbourhood_Kensington',
#  'neighbourhood_Kingsbridge',
#  'neighbourhood_Kingsbridge Heights',
#  'has_reviews',
#  'neighbourhood_Lindenwood',
#  'neighbourhood_Little Italy',
#  'neighbourhood_Longwood',
#  'neighbourhood_Marble Hill',
#  'neighbourhood_Marine Park',
#  'neighbourhood_Mariners Harbor',
#  'neighbourhood_Maspeth',
#  'neighbourhood_Meiers Corners',
#  'neighbourhood_Middle Village',
#  'neighbourhood_Midland Beach',
#  'neighbourhood_Highbridge']
